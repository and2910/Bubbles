# %% [markdown]
# ## Negative Selection data preparation and file creation

# %%
import numpy as np
import pandas as pd
import glob
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore

# %%
sns_files = pd.read_csv(r'C:\Users\B420615\OneDrive - Standard Bank\Py\SNS_Control.csv')

# %%
sns_files = sns_files['Files'].tolist()

# %%
path = glob.glob(r'C:\Users\B420615.STANLIB\Neg_Sel\*.csv')

#create two lists of desired column names - one for all columns and one for data columns
adjcols = ['Date','Ticker','Name','BM','AdjfcfY','CECP','TR_1M','Price','FCFY','MCap','TR_12-1','best_eps_chg','rec_chg12M','tp_chg','fcf_me','fcf_at','seas_1_1an','rec_chg']
data_cols = ['BM','AdjfcfY','CECP','TR_1M','Price','FCFY','MCap','TR_12-1','best_eps_chg','rec_chg12M','tp_chg','fcf_me','fcf_at','seas_1_1an','rec_chg']
cols_with_commas = ['Price','MCap']
cols_to_avg = ['BM','AdjfcfY','TR_1M','FCFY','TR_12-1','best_eps_chg','rec_chg12M','tp_chg','fcf_me','fcf_at','seas_1_1an']
cols_to_zero = ['CECP']
excl_cols = ['rec_chg']

# %%
for file in sns_files[:]:
    try:
        sentiment_df = pd.read_csv(rf'C:\Users\B420615\OneDrive - Standard Bank\Neg_Sel\{file}.csv', thousands=',')
        # clean data so that all values, apart from naming values, and including NaNs, are reflected as float values. Delete unneeded column
        sentiment_df = sentiment_df[Neg_Sel_df['Ticker'].notna()]
        sentiment_df.replace('N.A.', np.nan, inplace=True)
        sentiment_df.drop(['EPS_ESTIMATE_CHG'], axis=1, inplace=True)
        
        column_mapping = {
            'Date': 'Date',
            'Ticker': 'Ticker',
            'Short Name': 'Name',
            'BENEISH-M': 'BM',
            'AdjFCFYield': 'AdjfcfY',
            'ChgEstimateVSChgPrice': 'CECP',
            'Total Return:M-1': 'TR_1M',
            'FCF Yld:Y': 'FCFY',
            'TR_Momentum': 'TR_12-1',
            'best_eps_chg': 'best_eps_chg',
            'rec_chg_12M': 'rec_chg12M',
            'tp_change': 'tp_chg',
            'fcf_me': 'fcf_me',
            'fcf_at': 'fcf_at',
            'seas_1_1an': 'seas_1_1an',
            'rec_chg': 'rec_chg',
            'Market Cap': 'MCap',
            'Last Px': 'Price'
        }
        
        # Rename columns
        sentiment_df = sentiment_df.rename(columns=column_mapping)
        
        def convert_to_float(value):
            if isinstance(value, str):
                value = value.replace(',', '')
                try:
                    return float(value)
                except ValueError:
                    return None
            return value
        
        sentiment_df[data_cols] = sentiment_df[data_cols].apply(lambda col: col.map(convert_to_float))
        
        for col in cols_to_avg:
            if col in sentiment_df.columns:
                mean_value = Neg_Sel_df[col].astype(float).mean()
                Neg_Sel_df[col] = Neg_Sel_df[col].fillna(mean_value)
        
        # FIXED: Calculate z-scores for columns EXCLUDING seas_1_1an and rec_chg
        # These will be calculated separately after dropping NAs
        cols_for_first_zscore = [col for col in Neg_Sel_df.columns[3:-2] if col not in ['seas_1_1an', 'rec_chg']]
        z_scores = Neg_Sel_df[cols_for_first_zscore].apply(zscore)
        z_scores.columns = [f'z_{col}' for col in cols_for_first_zscore]
        Neg_Sel_df = pd.concat([Neg_Sel_df, z_scores], axis=1)
        
        excl_stocks = []
        for index, row in Neg_Sel_df.iterrows():
            if pd.isna(row['seas_1_1an']) or pd.isna(row['rec_chg']):
                excl_stocks.append(row['Ticker'])
        
        # Drop rows with NAs in seas_1_1an or rec_chg
        sentiment_df = sentiment_df.dropna(subset=['seas_1_1an', 'rec_chg'])
        
        # NOW calculate z scores for seas_1_1an and rec_chg (after dropping NAs)
        z_scores = sentiment_df[excl_cols].apply(zscore)
        z_scores.columns = ['z_seas_1_1an', 'z_rec_chg']
        sentiment_df = pd.concat([sentiment_df, z_scores], axis=1)
        
        # Calculate z-scores using specified weights
        sentiment_df['Sentiment'] = (sentiment_df['z_CECP']*0.2) + (sentiment_df['z_best_eps_chg']*0.2) + (sentiment_df['z_tp_chg']*0.2) + (sentiment_df['z_rec_chg']*0.2) + (sentiment_df['z_seas_1_1an']*0.1) + (sentiment_df['z_TR_1M']*-0.1)
        
        # Divide universe into quintiles
        sentiment_df['S_Quintile'] = pd.qcut(sentiment_df['Sentiment'], q=5, labels=False) + 1
        
        # Save processed sentiment csv file
        output_file_path = rf'C:\Users\B420615\OneDrive - Standard Bank\Neg_Sel\sentimentl_S{file}Mod.csv'
        sentiment_df.to_csv(output_file_path, index=False)
        
    except Exception as e:
        print(f"Error processing file {file}: {e}")
# Out:
# C:\Users\B420615\AppData\Local\Temp\ipykernel_26708\1749648883.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Neg_Sel_df.replace('N.A.', np.nan, inplace=True)
# C:\Users\B420615\AppData\Local\Temp\ipykernel_26708\1749648883.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Neg_Sel_df.replace('N.A.', np.nan, inplace=True)
# C:\Users\B420615\AppData\Local\Temp\ipykernel_26708\1749648883.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Neg_Sel_df.replace('N.A.', np.nan, inplace=True)
# C:\Users\B420615\AppData\Local\Temp\ipykernel_26708\1749648883.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Neg_Sel_df.replace('N.A.', np.nan, inplace=True)
# C:\Users\B420615\AppData\Local\Temp\ipykernel_26708\1749648883.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Neg_Sel_df.replace('N.A.', np.nan, inplace=True)
# C:\Users\B420615\AppData\Local\Temp\ipykernel_26708\1749648883.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Neg_Sel_df.replace('N.A.', np.nan, inplace=True)
# Error processing file NS20041231: name 'sentiment_df' is not defined
# Error processing file NS20050131: name 'sentiment_df' is not defined
# Error processing file NS20050228: name 'sentiment_df' is not defined
# Error processing file NS20050331: name 'sentiment_df' is not defined
# Error processing file NS20050430: name 'sentiment_df' is not defined
# Error processing file NS20050531: name 'sentiment_df' is not defined
# C:\Users\B420615\AppData\Local\Temp\ipykernel_26708\1749648883.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Neg_Sel_df.replace('N.A.', np.nan, inplace=True)
# C:\Users\B420615\AppData\Local\Temp\ipykernel_26708\1749648883.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Neg_Sel_df.replace('N.A.', np.nan, inplace=True)
# C:\Users\B420615\AppData\Local\anaconda3\Lib\site-packages\pandas\core\apply.py:1081: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   results[i] = self.func(v, *self.args, **self.kwargs)
# C:\Users\B420615\AppData\Local\Temp\ipykernel_26708\1749648883.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Neg_Sel_df.replace('N.A.', np.nan, inplace=True)
# Error processing file NS20050630: name 'sentiment_df' is not defined
# Error processing file NS20050731: name 'sentiment_df' is not defined
# Error processing file NS20050831: name 'sentiment_df' is not defined
# Error processing file NS20050930: name 'sentiment_df' is not defined
# Error processing file NS20051031: name 'sentiment_df' is not defined
# Error processing file NS20051130: name 'sentiment_df' is not defined
# Error processing file NS20051231: name 'sentiment_df' is not defined
# Error processing file NS20060131: name 'sentiment_df' is not defined
# Error processing file NS20060228: name 'sentiment_df' is not defined
# Error processing file NS20060331: name 'sentiment_df' is not defined
# Error processing file NS20060430: name 'sentiment_df' is not defined
# Error processing file NS20060531: name 'sentiment_df' is not defined
# Error processing file NS20060630: name 'sentiment_df' is not defined
# Error processing file NS20060731: name 'sentiment_df' is not defined
# Error processing file NS20060831: name 'sentiment_df' is not defined
# Error processing file NS20060930: name 'sentiment_df' is not defined
# Error processing file NS20061031: name 'sentiment_df' is not defined
# Error processing file NS20061130: name 'sentiment_df' is not defined
# Error processing file NS20061231: name 'sentiment_df' is not defined
# Error processing file NS20070131: name 'sentiment_df' is not defined
# Error processing file NS20070228: name 'sentiment_df' is not defined
# Error processing file NS20070331: name 'sentiment_df' is not defined
# Error processing file NS20070430: name 'sentiment_df' is not defined
# Error processing file NS20070531: name 'sentiment_df' is not defined
# Error processing file NS20070630: name 'sentiment_df' is not defined
# Error processing file NS20070731: name 'sentiment_df' is not defined
# Error processing file NS20070831: name 'sentiment_df' is not defined
# Error processing file NS20070930: name 'sentiment_df' is not defined
# Error processing file NS20071031: name 'sentiment_df' is not defined
# Error processing file NS20071130: name 'sentiment_df' is not defined
# Error processing file NS20071231: name 'sentiment_df' is not defined
# Error processing file NS20080131: name 'sentiment_df' is not defined
# Error processing file NS20080229: name 'sentiment_df' is not defined
# Error processing file NS20080331: name 'sentiment_df' is not defined
# Error processing file NS20080430: name 'sentiment_df' is not defined
# Error processing file NS20080531: name 'sentiment_df' is not defined
# Error processing file NS20080630: name 'sentiment_df' is not defined
# Error processing file NS20080731: name 'sentiment_df' is not defined
# Error processing file NS20080831: name 'sentiment_df' is not defined
# Error processing file NS20080930: name 'sentiment_df' is not defined
# Error processing file NS20081031: name 'sentiment_df' is not defined
# Error processing file NS20081130: name 'sentiment_df' is not defined
# Error processing file NS20081231: name 'sentiment_df' is not defined
# Error processing file NS20090131: name 'sentiment_df' is not defined
# Error processing file NS20090228: name 'sentiment_df' is not defined
# Error processing file NS20090331: name 'sentiment_df' is not defined
# Error processing file NS20090430: name 'sentiment_df' is not defined
# Error processing file NS20090531: name 'sentiment_df' is not defined
# Error processing file NS20090630: name 'sentiment_df' is not defined
# Error processing file NS20090731: name 'sentiment_df' is not defined
# Error processing file NS20090831: name 'sentiment_df' is not defined
# Error processing file NS20090930: name 'sentiment_df' is not defined
# Error processing file NS20091031: name 'sentiment_df' is not defined
# Error processing file NS20091130: name 'sentiment_df' is not defined
# Error processing file NS20091231: name 'sentiment_df' is not defined
# Error processing file NS20100131: name 'sentiment_df' is not defined
# Error processing file NS20100228: name 'sentiment_df' is not defined
# Error processing file NS20100331: name 'sentiment_df' is not defined
# Error processing file NS20100430: name 'sentiment_df' is not defined
# Error processing file NS20100531: name 'sentiment_df' is not defined
# Error processing file NS20100630: name 'sentiment_df' is not defined
# Error processing file NS20100731: name 'sentiment_df' is not defined
# Error processing file NS20100831: name 'sentiment_df' is not defined
# Error processing file NS20100930: name 'sentiment_df' is not defined
# Error processing file NS20101031: name 'sentiment_df' is not defined
# Error processing file NS20101130: name 'sentiment_df' is not defined
# Error processing file NS20101231: name 'sentiment_df' is not defined
# Error processing file NS20110131: name 'sentiment_df' is not defined
# Error processing file NS20110228: name 'sentiment_df' is not defined
# Error processing file NS20110331: name 'sentiment_df' is not defined
# Error processing file NS20110430: name 'sentiment_df' is not defined
# Error processing file NS20110531: name 'sentiment_df' is not defined
# Error processing file NS20110630: name 'sentiment_df' is not defined
# Error processing file NS20110731: name 'sentiment_df' is not defined
# Error processing file NS20110831: name 'sentiment_df' is not defined
# Error processing file NS20110930: name 'sentiment_df' is not defined
# Error processing file NS20111031: name 'sentiment_df' is not defined
# Error processing file NS20111130: name 'sentiment_df' is not defined
# Error processing file NS20111231: name 'sentiment_df' is not defined
# Error processing file NS20120131: name 'sentiment_df' is not defined
# Error processing file NS20120229: name 'sentiment_df' is not defined
# Error processing file NS20120331: name 'sentiment_df' is not defined
# Error processing file NS20120430: name 'sentiment_df' is not defined
# Error processing file NS20120531: name 'sentiment_df' is not defined
# Error processing file NS20120630: name 'sentiment_df' is not defined
# Error processing file NS20120731: name 'sentiment_df' is not defined
# Error processing file NS20120831: name 'sentiment_df' is not defined
# Error processing file NS20120930: name 'sentiment_df' is not defined
# Error processing file NS20121031: name 'sentiment_df' is not defined
# Error processing file NS20121130: name 'sentiment_df' is not defined
# Error processing file NS20121231: name 'sentiment_df' is not defined
# Error processing file NS20130131: name 'sentiment_df' is not defined
# Error processing file NS20130228: name 'sentiment_df' is not defined
# Error processing file NS20130331: name 'sentiment_df' is not defined
# Error processing file NS20130430: name 'sentiment_df' is not defined
# Error processing file NS20130531: name 'sentiment_df' is not defined
# Error processing file NS20130630: name 'sentiment_df' is not defined
# Error processing file NS20130731: name 'sentiment_df' is not defined
# Error processing file NS20130831: name 'sentiment_df' is not defined
# Error processing file NS20130930: name 'sentiment_df' is not defined
# Error processing file NS20131031: name 'sentiment_df' is not defined
# Error processing file NS20131130: name 'sentiment_df' is not defined
# Error processing file NS20131231: name 'sentiment_df' is not defined
# Error processing file NS20140131: name 'sentiment_df' is not defined
# Error processing file NS20140228: name 'sentiment_df' is not defined
# Error processing file NS20140331: name 'sentiment_df' is not defined
# Error processing file NS20140430: name 'sentiment_df' is not defined
# Error processing file NS20140531: name 'sentiment_df' is not defined
# Error processing file NS20140630: name 'sentiment_df' is not defined
# Error processing file NS20140731: name 'sentiment_df' is not defined
# Error processing file NS20140831: name 'sentiment_df' is not defined
# Error processing file NS20140930: name 'sentiment_df' is not defined
# Error processing file NS20141031: name 'sentiment_df' is not defined
# Error processing file NS20141130: name 'sentiment_df' is not defined
# Error processing file NS20141231: name 'sentiment_df' is not defined
# Error processing file NS20150131: name 'sentiment_df' is not defined
# Error processing file NS20150228: name 'sentiment_df' is not defined
# Error processing file NS20150331: name 'sentiment_df' is not defined
# Error processing file NS20150430: name 'sentiment_df' is not defined
# Error processing file NS20150531: name 'sentiment_df' is not defined
# Error processing file NS20150630: name 'sentiment_df' is not defined
# Error processing file NS20150731: name 'sentiment_df' is not defined
# Error processing file NS20150831: name 'sentiment_df' is not defined
# Error processing file NS20150930: name 'sentiment_df' is not defined
# Error processing file NS20151031: name 'sentiment_df' is not defined
# Error processing file NS20151130: name 'sentiment_df' is not defined
# Error processing file NS20151231: name 'sentiment_df' is not defined
# Error processing file NS20160131: name 'sentiment_df' is not defined
# Error processing file NS20160229: name 'sentiment_df' is not defined
# Error processing file NS20160331: name 'sentiment_df' is not defined
# Error processing file NS20160430: name 'sentiment_df' is not defined
# Error processing file NS20160531: name 'sentiment_df' is not defined
# Error processing file NS20160630: name 'sentiment_df' is not defined
# Error processing file NS20160731: name 'sentiment_df' is not defined
# Error processing file NS20160831: name 'sentiment_df' is not defined
# Error processing file NS20160930: name 'sentiment_df' is not defined
# Error processing file NS20161031: name 'sentiment_df' is not defined
# Error processing file NS20161130: name 'sentiment_df' is not defined
# Error processing file NS20161231: name 'sentiment_df' is not defined
# Error processing file NS20170131: name 'sentiment_df' is not defined
# Error processing file NS20170228: name 'sentiment_df' is not defined
# Error processing file NS20170331: name 'sentiment_df' is not defined
# Error processing file NS20170430: name 'sentiment_df' is not defined
# Error processing file NS20170531: name 'sentiment_df' is not defined
# Error processing file NS20170630: name 'sentiment_df' is not defined
# Error processing file NS20170731: name 'sentiment_df' is not defined
# Error processing file NS20170831: name 'sentiment_df' is not defined
# Error processing file NS20170930: name 'sentiment_df' is not defined
# Error processing file NS20171031: name 'sentiment_df' is not defined
# Error processing file NS20171130: name 'sentiment_df' is not defined
# Error processing file NS20171231: name 'sentiment_df' is not defined
# Error processing file NS20180131: name 'sentiment_df' is not defined
# Error processing file NS20180228: name 'sentiment_df' is not defined
# Error processing file NS20180331: name 'sentiment_df' is not defined
# Error processing file NS20180430: name 'sentiment_df' is not defined
# Error processing file NS20180531: name 'sentiment_df' is not defined
# Error processing file NS20180630: name 'sentiment_df' is not defined
# Error processing file NS20180731: name 'sentiment_df' is not defined
# Error processing file NS20180831: name 'sentiment_df' is not defined
# Error processing file NS20180930: name 'sentiment_df' is not defined
# Error processing file NS20181031: name 'sentiment_df' is not defined
# Error processing file NS20181130: name 'sentiment_df' is not defined
# Error processing file NS20181231: name 'sentiment_df' is not defined
# Error processing file NS20190131: name 'sentiment_df' is not defined
# Error processing file NS20190228: name 'sentiment_df' is not defined
# Error processing file NS20190331: name 'sentiment_df' is not defined
# Error processing file NS20190430: name 'sentiment_df' is not defined
# Error processing file NS20190531: name 'sentiment_df' is not defined
# Error processing file NS20190630: name 'sentiment_df' is not defined
# Error processing file NS20190731: name 'sentiment_df' is not defined
# Error processing file NS20190831: name 'sentiment_df' is not defined
# Error processing file NS20190930: name 'sentiment_df' is not defined
# Error processing file NS20191031: name 'sentiment_df' is not defined
# Error processing file NS20191130: name 'sentiment_df' is not defined
# Error processing file NS20191231: name 'sentiment_df' is not defined
# Error processing file NS20200131: name 'sentiment_df' is not defined
# Error processing file NS20200229: name 'sentiment_df' is not defined
# Error processing file NS20200331: name 'sentiment_df' is not defined
# Error processing file NS20200430: name 'sentiment_df' is not defined
# Error processing file NS20200531: name 'sentiment_df' is not defined
# Error processing file NS20200630: name 'sentiment_df' is not defined
# Error processing file NS20200731: name 'sentiment_df' is not defined
# Error processing file NS20200831: name 'sentiment_df' is not defined
# Error processing file NS20200930: name 'sentiment_df' is not defined
# Error processing file NS20201031: name 'sentiment_df' is not defined
# Error processing file NS20201130: name 'sentiment_df' is not defined
# Error processing file NS20201231: name 'sentiment_df' is not defined
# Error processing file NS20210131: name 'sentiment_df' is not defined
# Error processing file NS20210228: name 'sentiment_df' is not defined
# Error processing file NS20210331: name 'sentiment_df' is not defined
# Error processing file NS20210430: name 'sentiment_df' is not defined
# Error processing file NS20210531: name 'sentiment_df' is not defined
# Error processing file NS20210630: name 'sentiment_df' is not defined
# Error processing file NS20210731: name 'sentiment_df' is not defined
# Error processing file NS20210831: name 'sentiment_df' is not defined
# Error processing file NS20210930: name 'sentiment_df' is not defined
# Error processing file NS20211031: name 'sentiment_df' is not defined
# Error processing file NS20211130: name 'sentiment_df' is not defined
# Error processing file NS20211231: name 'sentiment_df' is not defined
# Error processing file NS20220131: name 'sentiment_df' is not defined
# Error processing file NS20220228: name 'sentiment_df' is not defined
# Error processing file NS20220331: name 'sentiment_df' is not defined
# Error processing file NS20220430: name 'sentiment_df' is not defined
# Error processing file NS20220531: name 'sentiment_df' is not defined
# Error processing file NS20220630: name 'sentiment_df' is not defined
# Error processing file NS20220731: name 'sentiment_df' is not defined
# Error processing file NS20220831: name 'sentiment_df' is not defined
# Error processing file NS20220930: name 'sentiment_df' is not defined
# Error processing file NS20221031: name 'sentiment_df' is not defined
# Error processing file NS20221130: name 'sentiment_df' is not defined
# Error processing file NS20221231: name 'sentiment_df' is not defined
# Error processing file NS20230131: name 'sentiment_df' is not defined
# Error processing file NS20230228: name 'sentiment_df' is not defined
# Error processing file NS20230331: name 'sentiment_df' is not defined
# Error processing file NS20230430: name 'sentiment_df' is not defined
# Error processing file NS20230531: name 'sentiment_df' is not defined
# Error processing file NS20230630: name 'sentiment_df' is not defined
# Error processing file NS20230731: name 'sentiment_df' is not defined
# Error processing file NS20230831: name 'sentiment_df' is not defined
# Error processing file NS20230930: name 'sentiment_df' is not defined
# Error processing file NS20231031: name 'sentiment_df' is not defined
# Error processing file NS20231130: name 'sentiment_df' is not defined
# Error processing file NS20231231: name 'sentiment_df' is not defined
# Error processing file NS20240131: name 'sentiment_df' is not defined
# Error processing file NS20240229: name 'sentiment_df' is not defined
# Error processing file NS20240331: name 'sentiment_df' is not defined
# Error processing file NS20240430: name 'sentiment_df' is not defined
# Error processing file NS20240531: name 'sentiment_df' is not defined
# Error processing file NS20240630: name 'sentiment_df' is not defined
# Error processing file NS20240731: name 'sentiment_df' is not defined
# Error processing file NS20240831: name 'sentiment_df' is not defined
# Error processing file NS20240930: name 'sentiment_df' is not defined
# Error processing file NS20241031: name 'sentiment_df' is not defined
# Error processing file NS20241130: name 'sentiment_df' is not defined
# Error processing file NS20241231: name 'sentiment_df' is not defined
# Error processing file NS20250131: name 'sentiment_df' is not defined
# Error processing file NS20250228: name 'sentiment_df' is not defined
# Error processing file NS20250331: name 'sentiment_df' is not defined
# Error processing file NS20250430: name 'sentiment_df' is not defined
# Error processing file NS20250531: name 'sentiment_df' is not defined
# Error processing file NS20250630: name 'sentiment_df' is not defined
# Error processing file NS20250731: name 'sentiment_df' is not defined
# Error processing file NS20250831: name 'sentiment_df' is not defined
# Error processing file NS20250930: name 'sentiment_df' is not defined

# %%
# Create new analyst sentiment factor and test output

sentiment_df['an_sent'] = ((sentiment_df['z_best_eps_chg']/3) + (sentiment_df['z_tp_chg']/3) + (sentiment_df['z_rec_chg']/3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 # Create new analyst sentiment factor and test output
# ----> 3 sentiment_df['an_sent'] = ((sentiment_df['z_best_eps_chg']/3) + (sentiment_df['z_tp_chg']/3) + (sentiment_df['z_rec_chg']/3))
#
# NameError: name 'sentiment_df' is not defined
